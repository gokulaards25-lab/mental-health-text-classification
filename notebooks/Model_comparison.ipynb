# %%
svm_accuracy = 0.61
bert_accuracy = 0.75

# %%
import pandas as pd

comparison = pd.DataFrame({
    "Model": ["SVM (TF-IDF)", "BERT"],
    "Accuracy": [0.61, 0.75]
})

comparison
# Out:
#           Model  Accuracy
# 0  SVM (TF-IDF)      0.61
# 1          BERT      0.75

# %%
import matplotlib.pyplot as plt

plt.bar(comparison["Model"], comparison["Accuracy"])
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.show()
